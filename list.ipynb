# %% [markdown]
# ### List

# %%
my_list = [1,2,3,4,5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(my_list[0])   # prints first item from list

print(my_list[-1])  # prints last item from list
# Out:
# 1

# %%
my_list = [1,2,3,4,5,6]
my_list.append(7)
print(my_list)  # adding new element to end of list
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
# modifying elements of list by accessing their index number

my_list[0] = 10
print(my_list)
# Out:
# [10, 2, 3, 4, 5, 6, 7]

# %%
## inserting elements at specific position using Insert

my_list.insert(2,14)
print(my_list)
# Out:
# [10, 2, 14, 3, 4, 5, 6, 7]

# %%
## using pop method to remove element at specific index

my_list.pop(3)
print(my_list)
# Out:
# [2, 14, 3, 5, 6, 7]

# %%
print(len(my_list))
# Out:
# 6

# %%
# list of numbers 

num_list = [1,2,3,4]
print(num_list)

# list of strings
fruits = ['apple','orange','guvava']
print(fruits)

# list of mixed data types
mix_list = [1,'orange',3.14,True]
print(mix_list)

# nested list
nest = [[1,2,3],[5,6,7]]
print(nest)

#list of tuples
list_tuples = [('apple',1),('banana',2),('orange',5)]
print(list_tuples)

# list of dictionaries
dict_list = [{'name':'john','age':25},{'name':'gaz','age':45}]
print(dict_list)

# empty list
empty_list = []
print(empty_list)
# Out:
# [1, 2, 3, 4]
# ['apple', 'orange', 'guvava']
# [1, 'orange', 3.14, True]
# [[1, 2, 3], [5, 6, 7]]
# [('apple', 1), ('banana', 2), ('orange', 5)]
# [{'name': 'john', 'age': 25}, {'name': 'gaz', 'age': 45}]
# []

# %%
## Problems

### 1. find sum of all elements in list

l = [1,2,3,6,4,7]

duplicate = [1,1,2,3,3,3,4,4,9,9]

sum = 0

for i in l:
    sum = sum+i
print('sum of all the numbers in list is ',sum)

### 2. find largest and smallest element in list

smallest = min(l)
largest = max(l)

print('smallest number in list is',smallest,'and largest number in list is',largest)

### 3. remove duplicates from list

unique = list(set(duplicate))

print('unique elements in a list:',unique)

### 4. find second largest number in list

l.sort(reverse=True)
second_largest = l[1]
print('second largest object in list is ',second_largest)

### 5. sort list of integers in ascending order

l.sort(reverse=False)
print(l)

##6. reverse a list
l.sort(reverse=True)
print(l)

### check if list is empty

n = []

if len(l) == 0:
    print('list is empty')
else:
    print('list not empty')

### find common elements between two lists

l1 = [1,2,3,4]
l2 = [4,5,6,7,9]

common = set(l1) & set(l2)
print('common elements in two lists are',(common))

### find union of two lists

union1 = set(l1).union(l2)
union2 = set(l1)|set(l2)

print('union-1',union1,'union-2',union2)

### find intersection of two lists

inter1 = set(l1).intersection(l2)
inter2 = set(l1) & set(l2)

print('inter-1',inter1,'inter-2',inter2)

### find shortest string in list

s = ['apple','guava','orange','ladyfinger','chi']

shortest_string = min(s,key=len)
print('shortest string is',shortest_string)

### check if list is in ascending order or not

ne = [1,2,3,4,5]
def is_ascending(ne):
    return ne == sorted(ne)

print(is_ascending(ne))

### remove all even number from list

 # check if even or not

def remove_even(lst):
    odd_lst=[]
    for n in lst:
        if n%2!=0:
            lst.remove(n)
    return lst

print('even numbers are ',remove_even(l))

### program to check if one list is a subset of other list

l1 = [1,2,3,4,5,6]
l2 = [5,7]

if set(l2).issubset(set(l1)):
    print('list 2 is subset of list 1')
else:
    print('list 2 is not a subset of list 1')

### find largest three numbers in the list

l1 = [1,2,3,4,5,6,7]

## 1st way to solve
# l1.sort(reverse=True)
# print('three largest numbers from the list are ',l1[0],l1[1],l1[2])

## 2nd way to solve
largest_numbers = sorted(l1,reverse=True)[:4]
print('three largest numbers from the list are ',largest_numbers)


### program to remove all duplicate from a list of string

s = ['apple','guava','santra','banana','apple','apple','banana']

n  = set(s)
print('string left after removing duplicate strings',n)


### Given a list of strings, write a program to sort the strings in alphabetical order.

lst = sorted(n,reverse=False)
print('sorting all the strings in alphabetical order ',lst)

# Write a program to find the frequency of each element in a list.

def frequency(lst):
    frequency={}

    for item in lst:
        if item in frequency:
            frequency[item]+= 1
        else:
            frequency[item] = 1
    return frequency

print(frequency(s))

### Given a list of tuples, where each tuple represents a student's name and their score in a test,
### write a program to find the student with the highest score.

scores = [('sam',60),('varun',25),('manny',30),('krish',45)]
max_score = max(scores,key=lambda x:x[1])
print(max_score)

# Write a program to reverse a list in place (without creating a new list).
# scores = [('sam',60),('varun',25),('manny',30),('krish',45)]
# w = sorted(scores,reverse=True)
# print('reverse list ',w)


l1 = [1,2,3,4,5,10,14]
def rev(lst):
    lst.reverse()
    return lst

('reverse list',rev(scores))

# Given a list of integers, write a program to find the two elements whose sum is closest to zero.


le = [1,-1,2,3,5]
def closest(lst):
    for i in lst:
        for j in lst:
            s= i+j
            if s == 1:
                print('near zero',i,j,s)
                break
        else:
            continue
        break
    else:
        print('not near zero')

closest(le)


# Write a program to shuffle a given list randomly.
import random

random.shuffle(l1)
print('randomly shuffled list:',l1)

# Given a list of integers, write a program to check if there exists a triplet (a,b,c) such that a^2 + b^2 = c^2.

def triplet(lst1):
    for i in lst1:
        for j in lst1:
            s = i**2 + j**2
            if s in set(x**2 for x in lst1):
                print('triplet',i,j,int(s**0.5))
                break
        else:
            continue
        break
    else:
        print('no triplets in list')

lst1 = [2,3,4,6,8,9,10]

triplet(lst1)

# Write a program to find the second largest element in a list of integers.

second_largest = sorted(l1,reverse=True)[1]
print('second largest element in list is ',second_largest)

# Write a program to find the largest number in a list that is less than a given number.

n = 10

ls =[3,5,7,9,10,14]

for i in ls:
    if i < n:
        print(i)
        break
    else:
        break
else:
    print('no')
# Out:
# sum of all the numbers in list is  23
# smallest number in list is 1 and largest number in list is 7
# unique elements in a list: [1, 2, 3, 4, 9]
# second largest object in list is  6
# [1, 2, 3, 4, 6, 7]
# [7, 6, 4, 3, 2, 1]
# list not empty
# common elements in two lists are {4}
# union-1 {1, 2, 3, 4, 5, 6, 7, 9} union-2 {1, 2, 3, 4, 5, 6, 7, 9}
# inter-1 {4} inter-2 {4}
# shortest string is chi
# True
# even numbers are  [6, 4, 2]
# list 2 is not a subset of list 1
# three largest numbers from the list are  [7, 6, 5, 4]
# string left after removing duplicate strings {'santra', 'apple', 'banana', 'guava'}
# sorting all the strings in alphabetical order  ['apple', 'banana', 'guava', 'santra']
# {'apple': 3, 'guava': 1, 'santra': 1, 'banana': 2}
# ('sam', 60)
# near zero -1 2 1
# randomly shuffled list: [2, 4, 1, 10, 5, 3, 14]
# triplet 6 8 10
# second largest element in list is  10
# 3

# %%
lst = [1, 5, 10, 15, 20]
given_num = 5
result = max([x for x in lst if x < given_num])
print(result)
# Out:
# 1

# %%
# Given a list of integers, write a program to check if there exists a triplet (a,b,c) such that a^2 + b^2 = c^2.

lst1 = [2,3,5,12]
lst2 = [2,8,4,10]

for i in lst1:
    for j in lst2:
        s = i**2 + j**2
        if s in set(x**2 for x in lst1 or lst2):
            print('triplet:', i, j, int(s**0.5))
            break
    else:
        continue
    break
else:
    print('no triplets')

# %%
## Problems

### 1. find sum of all elements in list

lst = [1,2,3,4,5,12,15]

sum=0

for l in lst:
    sum=l+sum
print('sum of all the numbers in list is ',sum)

### 2. find largest and smallest element in list

for l in lst:
    largest = max(lst)
    smallest = min(lst)
print('largest',largest,' smallest',smallest)

### 3. remove duplicates from list

duplicate_list = [1,1,1,3,3,4,2,3,3,2,6]

duplicate = set(duplicate_list)

print('list without duplicates is ',duplicate)

### 4. find second largest number in list

l = sorted(lst,reverse=True)[1]
print('second largest number in list',l)

### 5. sort list of integers in ascending order

n = [14,12,3,5,9]
sort = sorted(n,reverse=False)
print('list sorted in ascending order ',sort)

### 6. reverse a list

n.reverse()
print('reversed list ',n)

### 7. check if list is empty
## 1st  way
new=[]

if len(new) == 0:
    print('empty')
else:
    print('not empty')

## 2nd way

new=[3]

if not new:
    print('empty')
else:
    print('not empty')

### 8. find common elements between two lists

lst1 = [2,3,4,5,10]
lst2 = [1,2,11,14]

common = set(lst1) & set(lst2)
# print('common values in both sets are ',common)

if common in lst1 and lst2:
    print('common available')
else:
    print('common not available')

### 9. find union of two lists

union = set(lst1)|set(lst2)
print('union of two list is ',union)

### 10.find intersection of two lists

intersection  = set(lst1) & set(lst2)
print('intersection of two list is ',intersection)

### 11.find shortest string in list

string = ['apple','orange','kiwi','sugarcane','cat']


shortest = min(string,key=len)
print('shortest word in string list is ',shortest)

### check if list is in ascending order or not

me = [14,16,18,4,3,7]

if me == sorted(me,reverse=False):
    print(me,'in ascending order')
else:
    print('not ascending order')

### remove all even number from list

me = [1,2,3,8,10,11,19,25]

new_me = []
for m in me:
    if m%2!=0:
        new_me.append(m)
print('new list',new_me)


### program to check if one list is a subset of other list
sub = [1,8,11]

if set(sub).issubset(set(me)):
    print('subset')
else:
    print('not subset')

### find largest three numbers in the list
lar = sorted(me,reverse=True)[:3]
print('largest three numbers of list is ',lar)


### program to remove all duplicate from a list of string
string = ['apple','apple','banana','car','car','car']
ls = set(string)
print('after removing all duplicates from list',ls)

### Given a list of strings, write a program to sort the strings in alphabetical order.
so = sorted(set(string),reverse=False)
print('fruits in their alphabetical order',so)

### Write a program to find the frequency of each element in a list.

### Given a list of tuples, where each tuple represents a student's name and their score in a test,write a program to find the student with the highest score.
tup = [('varun',50),('gaurav',65),('sam',40)]

t = max(tup,key=lambda x:x[1])
print(t)

### Write a program to reverse a list in place (without creating a new list).

l1 = [24,32,12,100,12]
l1.reverse()
print(l1)

### Given a list of integers, write a program to find the two elements whose sum is closest to zero.


### Write a program to shuffle a given list randomly.
import random

random.shuffle(l1)
print(l1)

### Given a list of integers, write a program to check if there exists a triplet (a,b,c) such that a^2 + b^2 = c^2.

### Write a program to find the second largest element in a list of integers.
second = sorted(l1,reverse=True)[1]
print('second largest number in list is ',second)

### Write a program to find the largest number in a list that is less than a given number.

l1 = [24,32,22,100,12]
given_number = 25

for i in l1:
    if i<given_number:
        print('highest number which is smaller than entered number',i)
    else:
        break
else:
    print('no')
# Out:
# sum of all the numbers in list is  42
# largest 15  smallest 1
# list without duplicates is  {1, 2, 3, 4, 6}
# second largest number in list 12
# list sorted in ascending order  [3, 5, 9, 12, 14]
# reversed list  [9, 5, 3, 12, 14]
# empty
# not empty
# common not available
# union of two list is  {1, 2, 3, 4, 5, 10, 11, 14}
# intersection of two list is  {2}
# shortest word in string list is  cat
# not ascending order
# new list [1, 3, 11, 19, 25]
# subset
# largest three numbers of list is  [25, 19, 11]
# after removing all duplicates from list {'car', 'apple', 'banana'}
# fruits in their alphabetical order ['apple', 'banana', 'car']
# ('gaurav', 65)
# [12, 100, 12, 32, 24]
# [100, 12, 24, 12, 32]
# second largest number in list is  32
# highest number which is smaller than entered number 24

# %%
n = 10

ls =[3,5,7,9,10,14]

for i in ls:
    if i < n:
        print(i)
        break
    else:
        break
else:
    print('no')
# Out:
# 3

# %%
l = [1,2,3,6,4,7]

duplicate = [1,1,2,3,3,3,4,4,9,9]

sum = 0

for i in l:
    sum = sum+i
print('sum of all the numbers in list is ',sum)
